# %%
import pandas as pd

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.all-data', header = None, prefix = 'f')

# %%
df.head(5)
# Out:
#        f0      f1      f2      f3      f4      f5      f6      f7      f8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        f9     f10     f11     f12     f13     f14     f15     f16     f17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
#       f18     f19     f20     f21     f22     f23     f24 ...      f36  \
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.rename(columns={'f60':'Label'}, inplace=True)

# %%
df.head(1)
# Out:
#      f0      f1      f2      f3      f4      f5      f6      f7      f8  \
# 0  0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
#
#        f9     f10     f11     f12     f13    f14     f15   f16     f17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.066  0.2273  0.31  0.2999
#
#       f18     f19     f20     f21     f22    f23     f24  ...       f36  \
# 0  0.5078  0.4797  0.5783  0.5071  0.4328  0.555  0.6711  ...    0.6692
#
#       f37     f38     f39    f40     f41     f42     f43     f44     f45  \
# 0  0.6097  0.4943  0.2744  0.051  0.2834  0.2825  0.4256  0.2641  0.1386
#
#       f46     f47     f48     f49     f50     f51     f52     f53     f54  \
# 0  0.1051  0.1343  0.0383  0.0324  0.0232  0.0027  0.0065  0.0159  0.0072
#
#       f55    f56     f57    f58     f59  Label
# 0  0.0167  0.018  0.0084  0.009  0.0032      R
#
# [1 rows x 61 columns]

# %%
df_cat = pd.get_dummies(df['Label'])

# %%
df['is_M'] = df_cat['M']

# %%
df.head(5)
# Out:
#        f0      f1      f2      f3      f4      f5      f6      f7      f8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        f9     f10     f11     f12     f13     f14     f15     f16     f17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
#       f18     f19     f20     f21     f22     f23     f24  ...      f37  \
# ...

# %%
df.is_M.dtype
# Out:
# dtype('uint8')

# %%
df1 = df

# %%
del df1['Label']

# %%
del df1['is_M']

# %%
df1.head(5)
# Out:
#        f0      f1      f2      f3      f4      f5      f6      f7      f8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        f9     f10     f11     f12     f13     f14     f15     f16     f17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
# ...

# %%
df2 = df1.corr()

# %%
df2
# Out:
#            f0        f1        f2        f3        f4        f5        f6  \
# f0   1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# f1   0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# f2   0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# f3   0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# f4   0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# f5   0.238921  0.332329  0.346275  0.352805  0.597053  1.000000  0.702889
# f6   0.260815  0.279040  0.190434  0.246440  0.335422  0.702889  1.000000
# f7   0.355523  0.334615  0.237884  0.246742  0.204006  0.471683  0.675774
# f8   0.353420  0.316733  0.252691  0.247078  0.177906  0.327578  0.470580
# f9   0.318276  0.270782  0.219637  0.237769  0.183219  0.288621  0.425448
# f10  0.344058  0.297065  0.274610  0.271881  0.231684  0.333570  0.396588
# f11  0.210861  0.194102  0.214807  0.175381  0.211657  0.344451  0.274432
# ...

# %%
import numpy as np

# %%
indices = np.where(df2 > 0.9)
indices = [(df2.index[x], df2.columns[y]) for x, y in zip(*indices)
                                       if x != y and x < y]
#indices

# %%
indices
# Out:
# [('f14', 'f15'), ('f16', 'f17'), ('f19', 'f20')]

# %%
#drop 14,16,19
